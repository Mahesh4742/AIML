# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/Mahesh/Downloads/youtubers_df.csv")
df
# Out:
#      Rank              Username           Categories   Suscribers  \
# 0       1               tseries       Música y baile  249500000.0
# 1       2               MrBeast   Videojuegos, Humor  183500000.0
# 2       3             CoComelon            Educación  165500000.0
# 3       4              SETIndia                  NaN  162600000.0
# 4       5         KidsDianaShow  Animación, Juguetes  113500000.0
# ..    ...                   ...                  ...          ...
# 995   996          hamzymukbang                  NaN   11700000.0
# 996   997            Adaahqueen                  NaN   11700000.0
# 997   998  LittleAngelIndonesia       Música y baile   11700000.0
# 998   999          PenMultiplex                  NaN   11700000.0
# 999  1000         OneindiaHindi  Noticias y Política   11700000.0
#
#             Country       Visits      Likes  Comments  \
# 0             India      86200.0     2700.0      78.0
# 1    Estados Unidos  117400000.0  5300000.0   18500.0
# ...

# %%
df['Country'].head(20)
# Out:
# 0              India
# 1     Estados Unidos
# 2            Unknown
# 3              India
# 4            Unknown
# 5     Estados Unidos
# 6            Unknown
# 7            Unknown
# 8              India
# 9     Estados Unidos
# 10    Estados Unidos
# 11             India
# 12             India
# 13             India
# 14             India
# 15    Estados Unidos
# 16             India
# 17           Unknown
# 18           Unknown
# 19            Brasil
# Name: Country, dtype: object

# %%
df2=df.replace('India',1).replace('Estados Unidos',2).replace('Unknown',0)

# %%
df2
# Out:
#      Rank              Username           Categories   Suscribers Country  \
# 0       1               tseries       Música y baile  249500000.0       1
# 1       2               MrBeast   Videojuegos, Humor  183500000.0       2
# 2       3             CoComelon            Educación  165500000.0       0
# 3       4              SETIndia                  NaN  162600000.0       1
# 4       5         KidsDianaShow  Animación, Juguetes  113500000.0       0
# ..    ...                   ...                  ...          ...     ...
# 995   996          hamzymukbang                  NaN   11700000.0       2
# 996   997            Adaahqueen                  NaN   11700000.0       1
# 997   998  LittleAngelIndonesia       Música y baile   11700000.0       0
# 998   999          PenMultiplex                  NaN   11700000.0       1
# 999  1000         OneindiaHindi  Noticias y Política   11700000.0       1
#
#           Visits      Likes  Comments  \
# 0        86200.0     2700.0      78.0
# ...

# %%
data ={'name':['a','b','c','d'],
      'gender':['male','male','female','male']}
df=pd.DataFrame(data)

# %%
df
# Out:
#   name  gender
# 0    a    male
# 1    b    male
# 2    c  female
# 3    d    male

# %%
a={'male':1,'female':0}
df2=df.replace("male", "0").replace("female", "1")

# %%
df2
# Out:
#   name gender
# 0    a      0
# 1    b      0
# 2    c      1
# 3    d      0

# %%
df.columns
# Out:
# Index(['Rank', 'Username', 'Categories', 'Suscribers', 'Country', 'Visits',
#        'Likes', 'Comments', 'Links'],
#       dtype='object')

# %%
plt.figure(figsize=(50,20))
plt.bar(df['Username'],df['Visits'])
plt.xlabel('channels')
plt.ylabel('visits')
plt.xticks(rotation=45) 
plt.tight_layout()

# %%
data=df.head(50)

plt.figure(figsize=(50,20))
plt.bar(data['Username'],data['Visits'])
plt.xlabel('channels')
plt.ylabel('visits')
plt.xticks(rotation=45) 
plt.tight_layout()

# %%
df=pd.read_csv('C:/Users/Mahesh/Downloads/Banglore.csv')

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='plasma')
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.head(20)
# Out:
#                area_type   availability                  location       size  \
# 0   Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1             Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2         Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3   Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4   Super built-up  Area  Ready To Move                  Kothanur      2 BHK
# 5   Super built-up  Area  Ready To Move                Whitefield      2 BHK
# 6   Super built-up  Area         18-May          Old Airport Road      4 BHK
# 7   Super built-up  Area  Ready To Move              Rajaji Nagar      4 BHK
# 8   Super built-up  Area  Ready To Move              Marathahalli      3 BHK
# 9             Plot  Area  Ready To Move              Gandhi Bazar  6 Bedroom
# 10  Super built-up  Area         18-Feb                Whitefield      3 BHK
# ...

# %%
mean=df['balcony'].mean()

# %%
df2=df.fillna(value= mean)

# %%
df2.head(20)
# Out:
#                area_type   availability                  location       size  \
# 0   Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1             Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2         Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3   Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4   Super built-up  Area  Ready To Move                  Kothanur      2 BHK
# 5   Super built-up  Area  Ready To Move                Whitefield      2 BHK
# 6   Super built-up  Area         18-May          Old Airport Road      4 BHK
# 7   Super built-up  Area  Ready To Move              Rajaji Nagar      4 BHK
# 8   Super built-up  Area  Ready To Move              Marathahalli      3 BHK
# 9             Plot  Area  Ready To Move              Gandhi Bazar  6 Bedroom
# 10  Super built-up  Area         18-Feb                Whitefield      3 BHK
# ...

# %%
df2.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# society         0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
sns.heatmap(df2.isnull(),yticklabels=False,cbar=False,cmap='plasma')
# Out:
# <Axes: >

# %%
dataset=[2,4,6,3,1,5,8,4,2,7,9,5,6,8,3,4,9,3,2,1,7,6,90,50,100]
plt.figure(figsize=(12,2))  
sns.boxplot(x=dataset)
plt.xlabel('dataset')
plt.title('Boxplot Example')
plt.show()
