# %%
    import pandas as pd
    df2 = pd.read_csv("C:/Users/Mahesh/Downloads/SPLITING.csv")
    df2.head()
# Out:
#   total_sqft  bath  balcony   price
# 0       1056   2.0      1.0   39.07
# 1       2600   5.0      3.0  120.00
# 2       1440   2.0      3.0   62.00
# 3       1521   3.0      1.0   95.00
# 4       1200   2.0      1.0   51.00

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=df2.fillna(value=0)

# %%
df
# Out:
#       total_sqft  bath  balcony   price
# 0           1056   2.0      1.0   39.07
# 1           2600   5.0      3.0  120.00
# 2           1440   2.0      3.0   62.00
# 3           1521   3.0      1.0   95.00
# 4           1200   2.0      1.0   51.00
# ...          ...   ...      ...     ...
# 13315       3453   4.0      0.0  231.00
# 13316       3600   5.0      0.0  400.00
# 13317       1141   2.0      1.0   60.00
# 13318       4689   4.0      1.0  488.00
# 13319        550   1.0      1.0   17.00
#
# [13320 rows x 4 columns]

# %%
plt.scatter(df['total_sqft'],df['price'])

# %%
plt.scatter(df['bath'],df['price'])

# %%
plt.scatter(df['bath'],df['balcony'])

# %%
x=df[['bath','balcony']]

# %%
y=df[['price']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train
# Out:
#        bath  balcony
# 8458    4.0      1.0
# 9085    3.0      2.0
# 5872    3.0      0.0
# 1050    3.0      1.0
# 6014    3.0      2.0
# ...     ...      ...
# 6349    2.0      1.0
# 9470    2.0      2.0
# 7153    2.0      1.0
# 13080   3.0      3.0
# 1771    4.0      0.0
#
# [9324 rows x 2 columns]

# %%
x_test
# Out:
#        bath  balcony
# 11532   3.0      1.0
# 3127    2.0      3.0
# 744     2.0      1.0
# 5078    3.0      3.0
# 6294    3.0      2.0
# ...     ...      ...
# 11171   2.0      1.0
# 6933    2.0      2.0
# 1803    2.0      3.0
# 5858    6.0      2.0
# 3291    6.0      0.0
#
# [3996 rows x 2 columns]

# %%
y_test
# Out:
#         price
# 11532   72.00
# 3127    73.00
# 744     22.00
# 5078    69.99
# 6294   120.00
# ...       ...
# 11171  200.00
# 6933    50.19
# 1803    39.00
# 5858    75.00
# 3291   375.00
#
# [3996 rows x 1 columns]

# %%
y_train
# Out:
#         price
# 8458   200.00
# 9085    69.89
# 5872   111.00
# 1050   235.00
# 6014   150.00
# ...       ...
# 6349    55.00
# 9470    35.00
# 7153    88.00
# 13080   62.00
# 1771   207.00
#
# [9324 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_sqft  13320 non-null  object
#  1   bath        13320 non-null  float64
#  2   balcony     13320 non-null  float64
#  3   price       13320 non-null  float64
# dtypes: float64(3), object(1)
# memory usage: 416.4+ KB

# %%
x_test
# Out:
#        bath  balcony
# 11532   3.0      1.0
# 3127    2.0      3.0
# 744     2.0      1.0
# 5078    3.0      3.0
# 6294    3.0      2.0
# ...     ...      ...
# 11171   2.0      1.0
# 6933    2.0      2.0
# 1803    2.0      3.0
# 5858    6.0      2.0
# 3291    6.0      0.0
#
# [3996 rows x 2 columns]

# %%
clf.predict(x_test)
# Out:
# array([[129.27059789],
#        [ 76.19902335],
#        [ 80.63615585],
#        ...,
#        [ 76.19902335],
#        [272.95535779],
#        [277.39249029]])

# %%
y_test
# Out:
#         price
# 11532   72.00
# 3127    73.00
# 744     22.00
# 5078    69.99
# 6294   120.00
# ...       ...
# 11171  200.00
# 6933    50.19
# 1803    39.00
# 5858    75.00
# 3291   375.00
#
# [3996 rows x 1 columns]

# %%
clf.score(x_test, y_test)
# Out:
# 0.2124064758121612

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=10)
x_test
# Out:
#        bath  balcony
# 76      2.0      3.0
# 5487    2.0      2.0
# 5195    3.0      0.0
# 2411    2.0      3.0
# 13217   3.0      0.0
# ...     ...      ...
# 1041    3.0      3.0
# 9766    4.0      1.0
# 10373   5.0      3.0
# 11314   5.0      1.0
# 149     5.0      0.0
#
# [3996 rows x 2 columns]

# %%
df.shape
# Out:
# (13320, 4)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split,KFold, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Sample data
y_true = x_test
y_pred = x_train

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_true, y_pred)
print("Mean Absolute Error (MAE):", mae)

# Calculate Root Mean Square Error (RMSE)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
print("Root Mean Square Error (RMSE):", rmse)

# Calculate R-squared (R2) score
r2 = r2_score(y_true, y_pred)
print("R-squared (R2) Score:", r2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 12
#       9 y_pred = x_train
#      11 # Calculate Mean Absolute Error (MAE)
# ---> 12 mae = mean_absolute_error(y_true, y_pred)
#      13 print("Mean Absolute Error (MAE):", mae)
#      15 # Calculate Root Mean Square Error (RMSE)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
# ...

# %%
df2
# Out:
#       total_sqft  bath  balcony   price
# 0           1056   2.0      1.0   39.07
# 1           2600   5.0      3.0  120.00
# 2           1440   2.0      3.0   62.00
# 3           1521   3.0      1.0   95.00
# 4           1200   2.0      1.0   51.00
# ...          ...   ...      ...     ...
# 13315       3453   4.0      0.0  231.00
# 13316       3600   5.0      NaN  400.00
# 13317       1141   2.0      1.0   60.00
# 13318       4689   4.0      1.0  488.00
# 13319        550   1.0      1.0   17.00
#
# [13320 rows x 4 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Generate synthetic data
np.random.seed(0)
X = np.random.rand(50,2)* 10

# Create a K-means model with 3 clusters
kmeans = KMeans(n_clusters=3, random_state=0)

# Fit the K-means model to the data
kmeans.fit(X)

# Get cluster labels and cluster centers
cluster_labels = kmeans.labels_
cluster_centers = kmeans.cluster_centers_

# Plot the data points and cluster centers
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=cluster_labels, cmap='plasma')
plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], c='red', marker='X', s=100, label='Cluster Centers')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('K-means Clustering')
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\Users\Mahesh\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Mahesh\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import LeaveOneOut
from sklearn.linear_model import LinearRegression

# Generate synthetic data
np.random.seed(0)
X = np.random.rand(100, 1) * 10
y = 2 * X + 1 + np.random.randn(100, 1)

# Initialize Leave-One-Out Cross-Validation
loo = LeaveOneOut()

# Initialize an array to store RMSE for each iteration
rmse_values =  []

# Perform Leave-One-Out Cross-Validation
for train_index, test_index in loo.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Fit a linear regression model on the training data
    model = LinearRegression()
    model.fit(X_train, y_train)

    # Make predictions on the test data point
    prediction = model.predict(X_test)

    
    # Calculate RMSE for this iteration
    rmse = np.sqrt((prediction - y_test) ** 2)
    rmse_values.append(rmse)

# Flatten the RMSE values array
rmse_values = np.array(rmse_values).flatten()

# Plot the RMSE values for each iteration
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(rmse_values) + 1), rmse_values, marker='o', linestyle='-')
plt.xlabel('Iteration')
plt.ylabel('RMSE')
plt.title('Leave-One-Out Cross-Validation with Linear Regression')
plt.grid()
plt.show()

# Calculate the average RMSE
average_rmse = np.mean(rmse_values)
print(f'Average RMSE: {average_rmse:.2f}')
# Out:
# Average RMSE: 0.87

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression

# Generate synthetic data
np.random.seed(0)
X = np.random.rand(100, 1) * 10
y = 2 * X + 1 + np.random.randn(100, 1)

# Number of folds for cross-validation
n_folds = 6

# Initialize a KFold cross-validation splitter
kf = KFold(n_splits=n_folds, shuffle=True, random_state=0)

# Initialize an array to store RMSE for each fold
rmse_values = []

# P

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Generate synthetic data
np.random.seed(0)
X = np.random.rand(50, 1) * 10
y = 2 * X + 1 + np.random.randn(50, 1)

# Split the data into a training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Fit a linear regression model on the training data
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
predictions = model.predict(X_test)

# Create a scatter plot for the linear regression
plt.figure(figsize=(8, 6))
plt.scatter(X_test, y_test, color='blue', label='Actual')
plt.scatter(X_test, predictions, color='red', marker='x', label='Predicted')
plt.plot(X_test, predictions, color='green', linewidth=2, label='Regression Line')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression with Holdout Method')
plt.legend()
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Generate synthetic data
np.random.seed(0)
X = np.random.rand(100, 1) * 10
y = 2 * X + 1 + np.random.randn(100, 1)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = X[:80], X[80:], y[:80], y[80:]

# Fit a linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
predictions = model.predict(X_test)

# Calculate squared errors for each prediction
squared_errors = (predictions - y_test) ** 2

# Calculate the overall RMSE
rmse = np.sqrt(mean_squared_error(y_test, predictions))

# Create a scatter plot for the linear regression with RMSE
plt.figure(figsize=(8, 6))
plt.scatter(X_test, y_test, color='blue', label='Actual')
plt.scatter(X_test, predictions, color='red', marker='x', label='Predicted')
plt.plot(X_test, predictions, color='green', linewidth=2, label='Regression Line')
plt.xlabel('X')
plt.ylabel('y')
plt.title(f'Linear Regression (RMSE: {rmse:.2f})')
plt.legend()
plt.grid()
plt.show()

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Generate synthetic data
np.random.seed(0)
X = np.random.rand(100, 1) * 10
y = 2 * X + 1 + np.random.randn(100, 1)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = X[:80], X[80:], y[:80], y[80:]

# Fit a linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
predictions = model.predict(X_test)

# Calculate R-squared
r_squared = r2_score(y_test, predictions)

print(f'R-squared: {r_squared:.2f}')
# Out:
# R-squared: 0.97
